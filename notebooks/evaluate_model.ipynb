# %%
# %load_ext autoreload
# %autoreload 2

import copy
import os.path as osp
import sys

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.stats import ttest_rel

sys.path.append('../src')
from eval_utils import calc_ap_score, compare_results, load_preds

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
eps = np.finfo("float").eps

plt.style.use(["science", "ieee"])
out_path = osp.join("../outputs/figures")

# %%
# Load data
dataset_mapping = {
    "pinterest": "Pinterest",
    "movielens": "MovieLens",
    "Clothing_Shoes_and_Jewelry": "Clothing",
    "Toys_and_Games": "Toys",
}

preds_dict = {}
for dataset_name, print_name in dataset_mapping.items():
    print(dataset_name)
    preds_dict[print_name] = load_preds(
        osp.join(f"../outputs/{dataset_name}/results.yaml")
    )
label_ratios = np.arange(0.1, 1.1, 0.1)
# Out:
# pinterest
# label_ratio_0.1_no_cf label_ratio_0.1_with_cf [0.091 0.146 60.440%]. size=(8119, 32)
# label_ratio_0.2_no_cf label_ratio_0.2_with_cf [0.117 0.169 44.440%]. size=(8119, 32)
# label_ratio_0.3_no_cf label_ratio_0.3_with_cf [0.270 0.308 14.070%]. size=(8119, 32)
# label_ratio_0.4_no_cf label_ratio_0.4_with_cf [0.294 0.326 10.880%]. size=(8119, 32)
# label_ratio_0.5_no_cf label_ratio_0.5_with_cf [0.316 0.338 6.960%]. size=(8119, 32)
# label_ratio_0.6_no_cf label_ratio_0.6_with_cf [0.329 0.347 5.470%]. size=(8119, 32)
# label_ratio_0.7_no_cf label_ratio_0.7_with_cf [0.331 0.349 5.440%]. size=(8119, 32)
# label_ratio_0.8_no_cf label_ratio_0.8_with_cf [0.333 0.350 5.110%]. size=(8119, 32)
# label_ratio_0.9_no_cf label_ratio_0.9_with_cf [0.334 0.351 5.090%]. size=(8119, 32)
# label_ratio_1.0_no_cf label_ratio_1.0_with_cf [0.338 0.355 5.030%]. size=(8119, 32)
# movielens
# label_ratio_0.1_no_cf label_ratio_0.1_with_cf [0.263 0.270 2.660%]. size=(3183, 19)
# label_ratio_0.2_no_cf label_ratio_0.2_with_cf [0.274 0.281 2.550%]. size=(3183, 19)
# label_ratio_0.3_no_cf label_ratio_0.3_with_cf [0.284 0.291 2.460%]. size=(3183, 19)
# label_ratio_0.4_no_cf label_ratio_0.4_with_cf [0.298 0.305 2.350%]. size=(3183, 19)
# label_ratio_0.5_no_cf label_ratio_0.5_with_cf [0.310 0.317 2.260%]. size=(3183, 19)
# label_ratio_0.6_no_cf label_ratio_0.6_with_cf [0.310 0.317 2.260%]. size=(3183, 19)
# label_ratio_0.7_no_cf label_ratio_0.7_with_cf [0.314 0.321 2.230%]. size=(3183, 19)
# label_ratio_0.8_no_cf label_ratio_0.8_with_cf [0.319 0.326 2.190%]. size=(3183, 19)
# label_ratio_0.9_no_cf label_ratio_0.9_with_cf [0.322 0.329 2.170%]. size=(3183, 19)
# label_ratio_1.0_no_cf label_ratio_1.0_with_cf [0.324 0.331 2.160%]. size=(3183, 19)
# Clothing_Shoes_and_Jewelry
# label_ratio_0.1_no_cf label_ratio_0.1_with_cf [0.194 0.224 15.460%]. size=(6766, 199)
# label_ratio_0.2_no_cf label_ratio_0.2_with_cf [0.273 0.293 7.330%]. size=(6766, 199)
# label_ratio_0.3_no_cf label_ratio_0.3_with_cf [0.295 0.312 5.760%]. size=(6766, 199)
# label_ratio_0.4_no_cf label_ratio_0.4_with_cf [0.319 0.335 5.020%]. size=(6766, 199)
# label_ratio_0.5_no_cf label_ratio_0.5_with_cf [0.335 0.346 3.280%]. size=(6766, 199)
# label_ratio_0.6_no_cf label_ratio_0.6_with_cf [0.343 0.355 3.500%]. size=(6766, 199)
# label_ratio_0.7_no_cf label_ratio_0.7_with_cf [0.355 0.365 2.820%]. size=(6766, 199)
# label_ratio_0.8_no_cf label_ratio_0.8_with_cf [0.355 0.365 2.820%]. size=(6766, 199)
# label_ratio_0.9_no_cf label_ratio_0.9_with_cf [0.363 0.370 1.930%]. size=(6766, 199)
# label_ratio_1.0_no_cf label_ratio_1.0_with_cf [0.368 0.373 1.360%]. size=(6766, 199)
# Toys_and_Games
# label_ratio_0.1_no_cf label_ratio_0.1_with_cf [0.078 0.098 25.640%]. size=(3572, 54)
# label_ratio_0.2_no_cf label_ratio_0.2_with_cf [0.167 0.180 7.780%]. size=(3572, 54)
# label_ratio_0.3_no_cf label_ratio_0.3_with_cf [0.288 0.308 6.940%]. size=(3572, 54)
# label_ratio_0.4_no_cf label_ratio_0.4_with_cf [0.313 0.334 6.710%]. size=(3572, 54)
# label_ratio_0.5_no_cf label_ratio_0.5_with_cf [0.338 0.358 5.920%]. size=(3572, 54)
# label_ratio_0.6_no_cf label_ratio_0.6_with_cf [0.357 0.376 5.320%]. size=(3572, 54)
# label_ratio_0.7_no_cf label_ratio_0.7_with_cf [0.369 0.381 3.250%]. size=(3572, 54)
# label_ratio_0.8_no_cf label_ratio_0.8_with_cf [0.390 0.401 2.820%]. size=(3572, 54)
# label_ratio_0.9_no_cf label_ratio_0.9_with_cf [0.400 0.410 2.500%]. size=(3572, 54)
# label_ratio_1.0_no_cf label_ratio_1.0_with_cf [0.397 0.407 2.520%]. size=(3572, 54)

# %% [markdown]
# # Plot performance

# %%
fig, axs = plt.subplots(1, 4, figsize=(6, 1.75))
for k, (dataset_name, performance_dict) in enumerate(preds_dict.items()):
    ax = axs[k]
    ax.plot(label_ratios, performance_dict["no_cf_ap"], label="Image-only")
    ax.plot(
        label_ratios,
        performance_dict["with_cf_ap"],
        label=r"$\text{MTL-reconstruct}_\text{\ uniform}$",
    )
    ax.set_xlabel("Label ratio \n\n ({}) {}".format(chr(k + 97), dataset_name))

plt.tight_layout()

# legend
fig.subplots_adjust(top=0.8)
handles, labels = axs[0].get_legend_handles_labels()
fig.legend(
    handles, labels, loc="upper center", ncol=2, frameon=True, bbox_to_anchor=[0.5, 1.0]
)

plt.savefig(osp.join(out_path, "ap.pdf"))
plt.show()

fig, axs = plt.subplots(1, 4, figsize=(6, 1.5))
for k, (dataset_name, performance_dict) in enumerate(preds_dict.items()):

    improvement = (
        100 * performance_dict["with_cf_ap"].round(3) / performance_dict["no_cf_ap"].round(3) - 100
    )
    improvement.round(1)

    ax = axs[k]
    ax.bar(label_ratios, improvement, width=0.075)
    ax.set_xlabel("Label ratio \n\n ({}) {}".format(chr(k + 97), dataset_name))
    ax.set_ylim(bottom=0.0)
axs[0].set_ylabel("Improvement (\%)")
plt.tight_layout()
plt.savefig(osp.join(out_path, "ap_improvement.pdf"))
plt.show()

# %% [markdown]
# # Table

# %%
metric_res_dicts = {}

# metric -> dataset -> performance dataframe
single_metric_res_dict = {}
single_metric_res_dict = compare_results(
    preds_dict, calc_ap_score, single_metric_res_dict
)
# Out:
# Pinterest
#  40%|████      | 4/10 [02:22<03:33, 35.60s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_6095/2842518701.py in <module>
#       3 # metric -> dataset -> performance dataframe
#       4 single_metric_res_dict = {}
# ----> 5 single_metric_res_dict = compare_results(
#       6     preds_dict, calc_ap_score, single_metric_res_dict
#       7 )
#
# ~/cactus/notebooks/../src/eval_utils.py in compare_results(preds_dict, eval_function, metric_dict)
#      35         no_cf_preds = dataset_dict["no_cf_preds"]
#      36         with_cf_preds = dataset_dict["with_cf_preds"]
# ---> 37         df = single_set_compare_results(
#      38             labels, no_cf_preds, with_cf_preds, eval_function
#      39         )
#
# ~/cactus/notebooks/../src/eval_utils.py in single_set_compare_results(labels, no_cf_pred_list, with_cf_pred_list, eval_function)
#      80     ):
#      81
# ---> 82         res_dict = single_label_ratio_compare_results(
#      83             label_ratio, labels, preds_a, preds_b, eval_function
#      84         )
#
# ~/cactus/notebooks/../src/eval_utils.py in single_label_ratio_compare_results(label_ratio, labels, preds_a, preds_b, eval_function)
#      50
#      51     # Evaluate performance
# ---> 52     perf_a = eval_function(labels, preds_a)
#      53     perf_b = eval_function(labels, preds_b)
#      54
#
# ~/cactus/notebooks/../src/eval_utils.py in calc_ap_score(labels, preds)
#     177         labels_chosen, preds_chosen = labels[idxs], preds[idxs]
#     178         mask = labels_chosen.sum(axis=0) > 0
# --> 179         ap = average_precision_score(labels_chosen[:, mask], preds_chosen[:, mask])
#     180         aps.append(ap)
#     181
#
# ~/anaconda3/envs/cactus/lib/python3.9/site-packages/sklearn/metrics/_ranking.py in average_precision_score(y_true, y_score, average, pos_label, sample_weight)
#     230         _binary_uninterpolated_average_precision, pos_label=pos_label
#     231     )
# --> 232     return _average_binary_score(
#     233         average_precision, y_true, y_score, average, sample_weight=sample_weight
#     234     )
#
# ~/anaconda3/envs/cactus/lib/python3.9/site-packages/sklearn/metrics/_base.py in _average_binary_score(binary_metric, y_true, y_score, average, sample_weight)
#      68         raise ValueError("average has to be one of {0}".format(average_options))
#      69
# ---> 70     y_type = type_of_target(y_true)
#      71     if y_type not in ("binary", "multilabel-indicator"):
#      72         raise ValueError("{0} format is not supported".format(y_type))
#
# ~/anaconda3/envs/cactus/lib/python3.9/site-packages/sklearn/utils/multiclass.py in type_of_target(y)
#     276         raise ValueError("y cannot be class 'SparseSeries' or 'SparseArray'")
#     277
# --> 278     if is_multilabel(y):
#     279         return "multilabel-indicator"
#     280
#
# ~/anaconda3/envs/cactus/lib/python3.9/site-packages/sklearn/utils/multiclass.py in is_multilabel(y)
#     170         )
#     171     else:
# --> 172         labels = np.unique(y)
#     173
#     174         return len(labels) < 3 and (
#
# <__array_function__ internals> in unique(*args, **kwargs)
#
# ~/anaconda3/envs/cactus/lib/python3.9/site-packages/numpy/lib/arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     258
#     259     """
# --> 260     ar = np.asanyarray(ar)
#     261     if axis is None:
#     262         ret = _unique1d(ar, return_index, return_inverse, return_counts)
#
# KeyboardInterrupt:

# %%
latex_dict = {}

preds_dict_cpy = copy.deepcopy(preds_dict)
for dataset_name, method_dict in preds_dict_cpy.items():

    image_only_pred = method_dict.pop("Image-only")
    labels = method_dict.pop("labels")

    ap_baseline = calc_ap_score(labels, image_only_pred)
    ap_baseline_mean = np.mean(ap_baseline)

    for method_name, method_pred in method_dict.items():
        ap = calc_ap_score(labels, method_pred)
        ap_pvalue = ttest_rel(ap_baseline, ap).pvalue.round(3)
        ap = np.mean(ap).round(3)
        ap_ratio = np.round(100 * (ap / ap_baseline_mean - 1.0), 1)
        ap_astrix = ""
        if ap_pvalue <= 0.05:
            ap_astrix = "*"
        if ap_pvalue <= 0.01:
            ap_astrix = "**"

        print(f"{method_name}")
        print(
            f'\t ap = {ap } ({"+" if ap_ratio>=0 else ""}{ap_ratio}%{ap_astrix}) \t {ap_pvalue=}'
        )

    print()
    print()

# %%
preds_dict_cpy['Pinterest'].keys()

# %%
['Image-only',
'Fine-tuning',
'Contrastive-loss',
'MTL-reconstruct_uniform',
'MTL-reconstruct_interaction',
'MTL-reconstruct_loss']
